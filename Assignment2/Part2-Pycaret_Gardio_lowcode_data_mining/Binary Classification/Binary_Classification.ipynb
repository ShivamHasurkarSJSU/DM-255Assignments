# %%
# !pip install pycaret
# !pip install gradio

# %%
from pycaret.classification import *
import pandas as pd
import gradio as gr

# %%
from google.colab import files
import io
uploaded = files.upload()
data_file = pd.read_csv(io.BytesIO(uploaded["AAPL(Apple) stock.csv"]))
data_file.head()
# Out:
#      <input type="file" id="files-5c56d180-0c8d-4aaa-b379-610c04cd55c7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5c56d180-0c8d-4aaa-b379-610c04cd55c7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data_file['Target'] = (data_file['Close'] > data_file['Open']).astype(int)

# %%
data_file.head(10)
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  2013-01-02  19.779285  19.821428  19.343929  19.608213  16.862818
# 1  2013-01-03  19.567142  19.631071  19.321428  19.360714  16.649981
# 2  2013-01-04  19.177500  19.236786  18.779642  18.821428  16.186199
# 3  2013-01-07  18.642857  18.903570  18.400000  18.710714  16.090986
# 4  2013-01-08  18.900356  18.996071  18.616072  18.761070  16.134293
# 5  2013-01-09  18.660713  18.750357  18.428213  18.467857  15.882133
# 6  2013-01-10  18.876785  18.882856  18.411428  18.696787  16.079004
# 7  2013-01-11  18.607143  18.761429  18.536428  18.582144  15.980417
# 8  2013-01-14  17.952856  18.125000  17.803928  17.919643  15.410674
# 9  2013-01-15  17.796429  17.821072  17.263571  17.354286  14.924473
#
#       Volume  Target
# 0  560518000       0
# 1  352965200       0
# 2  594333600       0
# 3  484156400       1
# 4  458707200       0
# 5  407604400       0
# 6  601146000       0
# 7  350506800       0
# ...

# %%
s = setup(data = data_file, target = 'Target')
# Out:
# <style type="text/css">
# #T_e2e00_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_e2e00" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e2e00_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_e2e00_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e2e00_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e2e00_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_e2e00_row0_col1" class="data row0 col1" >2268</td>
#     </tr>
#     <tr>
#       <th id="T_e2e00_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e2e00_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_e2e00_row1_col1" class="data row1 col1" >Target</td>
#     </tr>
#     <tr>
#       <th id="T_e2e00_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_bb57b th {
#   text-align: left;
# }
# ...

# %%
evaluate_model(best_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
pred_holdout = predict_model(best_model)
# Out:
# <style type="text/css">
# </style>
# <table id="T_24b15" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_24b15_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_24b15_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_24b15_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_24b15_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_24b15_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_24b15_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_24b15_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_24b15_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_24b15_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_24b15_row0_col0" class="data row0 col0" >Ridge Classifier</td>
# ...

# %%
lr = create_model('lr')
# Out:
# <style type="text/css">
# #T_5b40b_row10_col0, #T_5b40b_row10_col1, #T_5b40b_row10_col2, #T_5b40b_row10_col3, #T_5b40b_row10_col4, #T_5b40b_row10_col5, #T_5b40b_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_5b40b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5b40b_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_5b40b_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_5b40b_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_5b40b_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_5b40b_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_5b40b_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_5b40b_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %%
# !pip install gradio

# %%
create_app(lr)
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# Note: opening Chrome Inspector may crash demo inside Colab notebooks.
#
# To create a public link, set `share=True` in `launch()`.

# %%
save_model(best_model, 'best_bianry_class')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=FastMemory(location=/tmp/joblib),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['Open', 'High', 'Low', 'Close',
#                                               'Adj Close', 'Volume'],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=True,
#                                                                fill_value=None,
#                                                                keep_empty_features=False,
#                                                                missing_values=nan,
#                                                                strategy='mean',
#                                                                verbose='deprecated'))),
#                  ('categorical_imputer',
# ...
