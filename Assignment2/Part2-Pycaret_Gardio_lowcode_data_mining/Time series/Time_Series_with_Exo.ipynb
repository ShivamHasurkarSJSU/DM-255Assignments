# %%
import pandas as pd
import numpy as np
from pycaret.time_series import TSForecastingExperiment
# !pip install pycaret

# %%
from google.colab import files
import io
uploaded = files.upload()
data_file = pd.read_csv(io.BytesIO(uploaded["AAPL(Apple) stock.csv"]))
data_file.head()
# Out:
#      <input type="file" id="files-5afefb5d-00e1-451d-a31c-bd2a73828d97" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5afefb5d-00e1-451d-a31c-bd2a73828d97">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data_file["index"] = pd.to_datetime(data_file["Date"])
data_file.head()
# Out:
#          Date      Close     Volume      index
# 0  2013-01-02  19.608213  560518000 2013-01-02
# 1  2013-01-03  19.360714  352965200 2013-01-03
# 2  2013-01-04  18.821428  594333600 2013-01-04
# 3  2013-01-07  18.710714  484156400 2013-01-07
# 4  2013-01-08  18.761070  458707200 2013-01-08

# %%
data_file = data_file.drop(["Date"], axis = 1)
data_file.head()
# Out:
#        Close     Volume      index
# 0  19.608213  560518000 2013-01-02
# 1  19.360714  352965200 2013-01-03
# 2  18.821428  594333600 2013-01-04
# 3  18.710714  484156400 2013-01-07
# 4  18.761070  458707200 2013-01-08

# %%
data_file = data_file.set_index("index")
data_file.head()
# Out:
#                 Close     Volume
# index
# 2013-01-02  19.608213  560518000
# 2013-01-03  19.360714  352965200
# 2013-01-04  18.821428  594333600
# 2013-01-07  18.710714  484156400
# 2013-01-08  18.761070  458707200

# %%
exp = TSForecastingExperiment()

# %%
data_file.index = data_file.index.to_period('D')

# %%
import numpy as np
complete_index = pd.period_range(start=min(data_file.index), end=max(data_file.index), freq='D')
data_file = data_file.reindex(complete_index, fill_value=np.nan)
data_file.head()
# Out:
#                 Close       Volume
# 2013-01-02  19.608213  560518000.0
# 2013-01-03  19.360714  352965200.0
# 2013-01-04  18.821428  594333600.0
# 2013-01-05        NaN          NaN
# 2013-01-06        NaN          NaN

# %%
mean_value = data_file['Close'].mean()
data_file['Close'].fillna(value=mean_value, inplace=True)
data_file.head()
# Out:
#                 Close       Volume
# 2013-01-02  19.608213  560518000.0
# 2013-01-03  19.360714  352965200.0
# 2013-01-04  18.821428  594333600.0
# 2013-01-05  62.416599          NaN
# 2013-01-06  62.416599          NaN

# %%
mean_value = data_file['Volume'].mean()
data_file['Volume'].fillna(value=mean_value, inplace=True)
data_file.head()
# Out:
#                 Close        Volume
# 2013-01-02  19.608213  5.605180e+08
# 2013-01-03  19.360714  3.529652e+08
# 2013-01-04  18.821428  5.943336e+08
# 2013-01-05  62.416599  1.713540e+08
# 2013-01-06  62.416599  1.713540e+08

# %%
exp.setup(data_file, fh = 12, fold = 3, target = 'Close')
# Out:
# <style type="text/css">
# #T_a2dfd_row25_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_a2dfd" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a2dfd_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_a2dfd_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a2dfd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a2dfd_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_a2dfd_row0_col1" class="data row0 col1" >5579</td>
#     </tr>
#     <tr>
#       <th id="T_a2dfd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a2dfd_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_a2dfd_row1_col1" class="data row1 col1" >Close</td>
#     </tr>
#     <tr>
#       <th id="T_a2dfd_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best = exp.compare_models()
# Out:
# <style type="text/css">
# #T_24fbc th {
#   text-align: left;
# }
# ...

# %%
exp.plot_model(best)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
exp.plot_model(plot = 'ts')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
exp.plot_model(plot = 'diff')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
create_model = exp.create_model(best)
# Out:
# <style type="text/css">
# #T_32cac_row3_col0, #T_32cac_row3_col1, #T_32cac_row3_col2, #T_32cac_row3_col3, #T_32cac_row3_col4, #T_32cac_row3_col5, #T_32cac_row3_col6, #T_32cac_row3_col7 {
#   background: yellow;
# }
# </style>
# <table id="T_32cac" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_32cac_level0_col0" class="col_heading level0 col0" >cutoff</th>
#       <th id="T_32cac_level0_col1" class="col_heading level0 col1" >MASE</th>
#       <th id="T_32cac_level0_col2" class="col_heading level0 col2" >RMSSE</th>
#       <th id="T_32cac_level0_col3" class="col_heading level0 col3" >MAE</th>
#       <th id="T_32cac_level0_col4" class="col_heading level0 col4" >RMSE</th>
#       <th id="T_32cac_level0_col5" class="col_heading level0 col5" >MAPE</th>
#       <th id="T_32cac_level0_col6" class="col_heading level0 col6" >SMAPE</th>
#       <th id="T_32cac_level0_col7" class="col_heading level0 col7" >R2</th>
#     </tr>
# ...

# %%
predicted_model = exp.predict_model(create_model)
# Out:
# <style type="text/css">
# </style>
# <table id="T_beede" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_beede_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_beede_level0_col1" class="col_heading level0 col1" >MASE</th>
#       <th id="T_beede_level0_col2" class="col_heading level0 col2" >RMSSE</th>
#       <th id="T_beede_level0_col3" class="col_heading level0 col3" >MAE</th>
#       <th id="T_beede_level0_col4" class="col_heading level0 col4" >RMSE</th>
#       <th id="T_beede_level0_col5" class="col_heading level0 col5" >MAPE</th>
#       <th id="T_beede_level0_col6" class="col_heading level0 col6" >SMAPE</th>
#       <th id="T_beede_level0_col7" class="col_heading level0 col7" >R2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_beede_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_beede_row0_col0" class="data row0 col0" >ExtraTreesRegressor</td>
# ...

# %%
saved_model = exp.save_model(best, 'time_series_model_with_exogenuous_variables')
# Out:
# Transformation Pipeline and Model Successfully Saved

# %%
saved_model
# Out:
# (ForecastingPipeline(steps=[('forecaster',
#                              TransformedTargetForecaster(steps=[('model',
#                                                                  BaseCdsDtForecaster(fe_target_rr=[WindowSummarizer(lag_feature={'lag': [7,
#                                                                                                                                          6,
#                                                                                                                                          5,
#                                                                                                                                          4,
#                                                                                                                                          3,
#                                                                                                                                          2,
# ...
